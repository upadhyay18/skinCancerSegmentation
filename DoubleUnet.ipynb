# %%
# !unzip /content/drive/MyDrive/Segmentation/dataSet/ph2dataset.zip
# !rm -r /content/trainy
# !rm -r /content/trainx
# !rm -r /content/sample_data

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam

# %%
H = 256
W = 256

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def load_data(dataset_path, split=0.2):
    images = sorted(glob(os.path.join(dataset_path, "image", "*.bmp")))
    masks = sorted(glob(os.path.join(dataset_path, "mask", "*.bmp")))
    #print(type(images))
    test_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=test_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=test_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x                                ## (256, 256, 3)

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)                    ## (256, 256)
    x = np.expand_dims(x, axis=-1)              ## (256, 256, 1)
    x = np.concatenate([x, x], axis=-1)         ## (256, 256, 2)
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 2])
    return x, y

def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
# augmenting data
import cv2
from glob import glob
from albumentations import CenterCrop, RandomRotate90, HorizontalFlip, VerticalFlip
from tqdm import tqdm

def augment(images,masks,save_path,augment_data=True):
  H=256
  W=256
  for x,y in tqdm(zip(images,masks),total=len(images)):
    name=x.split('/')[-1].split(".")
    img_name=name[0]
    img_ext=name[1]

    name=x.split('/')[-1].split(".")
    mask_name=name[0]
    mask_ext=name[1]

    x=cv2.imread(x,cv2.IMREAD_COLOR)
    y=cv2.imread(y,cv2.IMREAD_COLOR)
    #print(x.shape)
    #print(y.shape)

    if augment_data==True:
      # Randome rotate
      aug=RandomRotate90(p=0.8)
      augmented=aug(image=x,mask=y)
      x2=augmented['image']
      y2=augmented['mask']
      # vertical Flip
      aug=VerticalFlip(p=0.6)
      augmented=aug(image=x,mask=y)
      x3=augmented['image']
      y3=augmented['mask']
      # Horizontal Flip Flip
      aug=HorizontalFlip(p=0.7)
      augmented=aug(image=x,mask=y)
      x4=augmented['image']
      y4=augmented['mask']
      #Save file
      save_images=[x,x2,x3,x4]
      save_masks=[y,y2,y3,y4]
    else:
      save_images=[x]
      save_masks=[y]
    idx=0
    for i,m in zip(save_images,save_masks):
      i=cv2.resize(i,(W,H))
      m=cv2.resize(m,(W,H))
      tmp_img_name=f"{img_name}_{idx}.{img_ext}"
      tmp_mask_name=f"{mask_name}_{idx}.{mask_ext}"
      image_path=os.path.join(save_path,"image",tmp_img_name)
      mask_path=os.path.join(save_path,"mask",tmp_mask_name)
      cv2.imwrite(image_path,i)
      cv2.imwrite(mask_path,m)
      idx+=1

# %%
create_dir("augDataset")
create_dir("augDataset/image")
create_dir("augDataset/mask")

# %%
path='/content/ph2_dataset'
images=sorted(glob(os.path.join(path,"trainx/*")))
masks=sorted(glob(os.path.join(path,"trainy/*")))
print(f"Orignal Image: {len(images)}")
print(f"Orignal Masks: {len(masks)}")
# Out:
# Orignal Image: 200
# Orignal Masks: 200

# %%
augment(images,masks,'/content/augDataset',True)
# Out:
# 100%|██████████| 200/200 [00:04<00:00, 42.86it/s]

# %%
path='/content/augDataset'
images=sorted(glob(os.path.join(path,"image/*")))
masks=sorted(glob(os.path.join(path,"mask/*")))
print(f"Augmented Image: {len(images)}")
print(f"Augmented Masks: {len(masks)}")
# Out:
# Augmented Image: 800
# Augmented Masks: 800

# %%
""" Folder For saving result"""
create_dir("Files")

# %%
# seeding 

np.random.seed(42)
tf.random.set_seed(42)

# %%
""" Hyperparameters """
batch_size = 16
lr = 1e-4 ## (0.0001)
num_epoch = 50

# %%
""" Dataset : 60/20/20 """
dataset_path = "/content/augDataset"
(train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

# %%
print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")
print(f"Test: {len(test_x)} - {len(test_y)}")
# Out:
# Train: 480 - 480
# Valid: 160 - 160
# Test: 160 - 160

# %%
train_dataset = tf_dataset(train_x, train_y, batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size)

# %%
train_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 256, 256, 2), dtype=tf.float32, name=None))>

# %%
train_steps = len(train_x)//batch_size
valid_steps = len(valid_x)//batch_size

# %%
if len(train_x) % batch_size != 0:
  train_steps += 1

if len(valid_x) % batch_size != 0:
  valid_steps += 1

# %% [markdown]
# **Double Unet Model Code**

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.layers import GlobalAveragePooling2D, Reshape, Dense, Multiply, AveragePooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19

def squeeze_excite_block(inputs, ratio=8):
    init = inputs       ## (b, 128, 128, 32)
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)     ## (b, 32)   -> (b, 1, 1, 32)
    se = Reshape(se_shape)(se)
    se = Dense(filters//ratio, activation="relu", use_bias=False)(se)
    se = Dense(filters, activation="sigmoid", use_bias=False)(se)

    x = Multiply()([inputs, se])
    return x

def ASPP(x, filter):
    shape = x.shape

    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filter, 1, padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation="bilinear")(y1)

    y2 = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(x)
    y2 = BatchNormalization()(y2)
    y2 = Activation("relu")(y2)

    y3 = Conv2D(filter, 3, dilation_rate=6, padding="same", use_bias=False)(x)
    y3 = BatchNormalization()(y3)
    y3 = Activation("relu")(y3)

    y4 = Conv2D(filter, 3, dilation_rate=12, padding="same", use_bias=False)(x)
    y4 = BatchNormalization()(y4)
    y4 = Activation("relu")(y4)

    y5 = Conv2D(filter, 3, dilation_rate=18, padding="same", use_bias=False)(x)
    y5 = BatchNormalization()(y5)
    y5 = Activation("relu")(y5)

    y = Concatenate()([y1, y2, y3, y4, y5])

    y = Conv2D(filter, 1, dilation_rate=1, padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)

    return y

def conv_block(x, filters):
    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = squeeze_excite_block(x)

    return x

def encoder1(inputs):
    skip_connections = []

    model = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)
    names = ["block1_conv2", "block2_conv2", "block3_conv4", "block4_conv4"]
    for name in names:
        skip_connections.append(model.get_layer(name).output)

    output = model.get_layer("block5_conv4").output
    return output, skip_connections

def decoder1(inputs, skip_connections):
    num_filters = [256, 128, 64, 32]
    skip_connections.reverse()

    x = inputs
    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2), interpolation="bilinear")(x)
        x = Concatenate()([x, skip_connections[i]])
        x = conv_block(x, f)

    return x

def output_block(inputs):
    x = Conv2D(1, 1, padding="same")(inputs)
    x = Activation("sigmoid")(x)
    return x

def encoder2(inputs):
    num_filters = [32, 64, 128, 256]
    skip_connections = []

    x = inputs
    for i, f in enumerate(num_filters):
        x = conv_block(x, f)
        skip_connections.append(x)
        x = MaxPool2D((2, 2))(x)

    return x, skip_connections

def decoder2(inputs, skip_1, skip_2):
    num_filters = [256, 128, 64, 32]
    skip_2.reverse()

    x = inputs
    for i, f in enumerate(num_filters):
        x = UpSampling2D((2, 2), interpolation="bilinear")(x)
        x = Concatenate()([x, skip_1[i], skip_2[i]])
        x = conv_block(x, f)

    return x

def build_model(input_shape):
    inputs = Input(input_shape)
    x, skip_1 = encoder1(inputs)
    x = ASPP(x, 64)
    x = decoder1(x, skip_1)
    output1 = output_block(x)

    x = inputs * output1

    x, skip_2 = encoder2(x)
    x = ASPP(x, 64)
    x = decoder2(x, skip_1, skip_2)
    output2 = output_block(x)
    outputs = Concatenate()([output1, output2])
    model = Model(inputs, outputs)
    return model


input_shape = (256, 256, 3)
model = build_model(input_shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
  return 1.0 - dice_coef(y_true, y_pred)

# %%
## compiling model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
metrics = [dice_coef, iou, Recall(), Precision()]
model.compile(loss="binary_crossentropy", optimizer=Adam(lr), metrics=metrics)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 256, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 256, 256, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 128, 128, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 128, 128, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 128, 128, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 64, 64, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 64, 64, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 64, 64, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 32, 32, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 32, 32, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 32, 32, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 512)  0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block5_conv3[0][0]']
#
#  average_pooling2d (AveragePool  (None, 1, 1, 512)   0           ['block5_conv4[0][0]']
#  ing2D)
#
#  conv2d (Conv2D)                (None, 1, 1, 64)     32832       ['average_pooling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1, 1, 64)    256         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 16, 16, 64)   32768       ['block5_conv4[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 64)   294912      ['block5_conv4[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 16, 16, 64)   294912      ['block5_conv4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 64)   294912      ['block5_conv4[0][0]']
#
#  activation (Activation)        (None, 1, 1, 64)     0           ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 64)   0           ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_2[0][0]']
#
#  activation_3 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_3[0][0]']
#
#  activation_4 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_4[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 320)  0           ['up_sampling2d[0][0]',
#                                                                   'activation_1[0][0]',
#                                                                   'activation_2[0][0]',
#                                                                   'activation_3[0][0]',
#                                                                   'activation_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 64)   20480       ['concatenate[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_5[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)  0           ['activation_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 576)  0           ['up_sampling2d_1[0][0]',
#                                                                   'block4_conv4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  1327360     ['concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_7[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['activation_7[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 256)    0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1, 1, 32)     8192        ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 256)    8192        ['dense[0][0]']
#
#  multiply (Multiply)            (None, 32, 32, 256)  0           ['activation_7[0][0]',
#                                                                   'dense_1[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 256)  0          ['multiply[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 512)  0           ['up_sampling2d_2[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 128)  589952      ['concatenate_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 128)  147584      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_9[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['activation_9[0][0]']
#  obalAveragePooling2D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 1, 1, 16)     2048        ['reshape_1[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 128)    2048        ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 64, 64, 128)  0           ['activation_9[0][0]',
#                                                                   'dense_3[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 12  0          ['multiply_1[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 25  0           ['up_sampling2d_3[0][0]',
#                                 6)                                'block2_conv2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 64  147520      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 64  256        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 64  36928       ['activation_10[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  activation_11 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  global_average_pooling2d_2 (Gl  (None, 64)          0           ['activation_11[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 1, 1, 8)      512         ['reshape_2[0][0]']
#
#  dense_5 (Dense)                (None, 1, 1, 64)     512         ['dense_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 128, 128, 64  0           ['activation_11[0][0]',
#                                 )                                 'dense_5[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 64  0          ['multiply_2[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 12  0           ['up_sampling2d_4[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 32  36896       ['concatenate_4[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 32  128        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 32  9248        ['activation_12[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 32  128        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_13[0][0]']
#                                 )
#
#  global_average_pooling2d_3 (Gl  (None, 32)          0           ['activation_13[0][0]']
#  obalAveragePooling2D)
#
#  reshape_3 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_6 (Dense)                (None, 1, 1, 4)      128         ['reshape_3[0][0]']
#
#  dense_7 (Dense)                (None, 1, 1, 32)     128         ['dense_6[0][0]']
#
#  multiply_3 (Multiply)          (None, 256, 256, 32  0           ['activation_13[0][0]',
#                                 )                                 'dense_7[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 1)  33          ['multiply_3[0][0]']
#
#  activation_14 (Activation)     (None, 256, 256, 1)  0           ['conv2d_14[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 256, 256, 3)  0           ['input_1[0][0]',
#                                                                   'activation_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 32  896         ['tf.math.multiply[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 32  128        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  9248        ['activation_15[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 32  128        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  global_average_pooling2d_4 (Gl  (None, 32)          0           ['activation_16[0][0]']
#  obalAveragePooling2D)
#
#  reshape_4 (Reshape)            (None, 1, 1, 32)     0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 1, 1, 4)      128         ['reshape_4[0][0]']
#
#  dense_9 (Dense)                (None, 1, 1, 32)     128         ['dense_8[0][0]']
#
#  multiply_4 (Multiply)          (None, 256, 256, 32  0           ['activation_16[0][0]',
#                                 )                                 'dense_9[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['multiply_4[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 64  36928       ['activation_17[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 64  256        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  global_average_pooling2d_5 (Gl  (None, 64)          0           ['activation_18[0][0]']
#  obalAveragePooling2D)
#
#  reshape_5 (Reshape)            (None, 1, 1, 64)     0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 1, 1, 8)      512         ['reshape_5[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1, 64)     512         ['dense_10[0][0]']
#
#  multiply_5 (Multiply)          (None, 128, 128, 64  0           ['activation_18[0][0]',
#                                 )                                 'dense_11[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['multiply_5[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_19[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_19[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 128)         0           ['activation_20[0][0]']
#  obalAveragePooling2D)
#
#  reshape_6 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 1, 1, 16)     2048        ['reshape_6[0][0]']
#
#  dense_13 (Dense)               (None, 1, 1, 128)    2048        ['dense_12[0][0]']
#
#  multiply_6 (Multiply)          (None, 64, 64, 128)  0           ['activation_20[0][0]',
#                                                                   'dense_13[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['multiply_6[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_21[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_21[0][0]']
#
#  global_average_pooling2d_7 (Gl  (None, 256)         0           ['activation_22[0][0]']
#  obalAveragePooling2D)
#
#  reshape_7 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_7[0][0
#                                                                  ]']
#
#  dense_14 (Dense)               (None, 1, 1, 32)     8192        ['reshape_7[0][0]']
#
#  dense_15 (Dense)               (None, 1, 1, 256)    8192        ['dense_14[0][0]']
#
#  multiply_7 (Multiply)          (None, 32, 32, 256)  0           ['activation_22[0][0]',
#                                                                   'dense_15[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['multiply_7[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 1, 1, 256)   0           ['max_pooling2d_3[0][0]']
#  oling2D)
#
#  conv2d_23 (Conv2D)             (None, 1, 1, 64)     16448       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 1, 1, 64)    256         ['conv2d_23[0][0]']
#  ormalization)
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 64)   16384       ['max_pooling2d_3[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 64)   147456      ['max_pooling2d_3[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 64)   147456      ['max_pooling2d_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 64)   147456      ['max_pooling2d_3[0][0]']
#
#  activation_23 (Activation)     (None, 1, 1, 64)     0           ['batch_normalization_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 64)  256         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 64)  256         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 16, 16, 64)  0           ['activation_23[0][0]']
#
#  activation_24 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_23[0][0]']
#
#  activation_25 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_25[0][0]']
#
#  activation_27 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_26[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 16, 16, 320)  0           ['up_sampling2d_5[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 64)   20480       ['concatenate_5[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_27[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 64)  0           ['activation_28[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 832)  0           ['up_sampling2d_6[0][0]',
#                                                                   'block4_conv4[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 256)  1917184     ['concatenate_6[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_29[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_29[0][0]']
#
#  global_average_pooling2d_8 (Gl  (None, 256)         0           ['activation_30[0][0]']
#  obalAveragePooling2D)
#
#  reshape_8 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_8[0][0
#                                                                  ]']
#
#  dense_16 (Dense)               (None, 1, 1, 32)     8192        ['reshape_8[0][0]']
#
#  dense_17 (Dense)               (None, 1, 1, 256)    8192        ['dense_16[0][0]']
#
#  multiply_8 (Multiply)          (None, 32, 32, 256)  0           ['activation_30[0][0]',
#                                                                   'dense_17[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 64, 64, 256)  0          ['multiply_8[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 640)  0           ['up_sampling2d_7[0][0]',
#                                                                   'block3_conv4[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 128)  737408      ['concatenate_7[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 128)  512        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_31[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 128)  512        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_31[0][0]']
#
#  global_average_pooling2d_9 (Gl  (None, 128)         0           ['activation_32[0][0]']
#  obalAveragePooling2D)
#
#  reshape_9 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_9[0][0
#                                                                  ]']
#
#  dense_18 (Dense)               (None, 1, 1, 16)     2048        ['reshape_9[0][0]']
#
#  dense_19 (Dense)               (None, 1, 1, 128)    2048        ['dense_18[0][0]']
#
#  multiply_9 (Multiply)          (None, 64, 64, 128)  0           ['activation_32[0][0]',
#                                                                   'dense_19[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 128, 128, 12  0          ['multiply_9[0][0]']
#                                 8)
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 32  0           ['up_sampling2d_8[0][0]',
#                                 0)                                'block2_conv2[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 64  184384      ['concatenate_8[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 128, 128, 64  256        ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 64  36928       ['activation_33[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 128, 128, 64  256        ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  global_average_pooling2d_10 (G  (None, 64)          0           ['activation_34[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_10 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_10[0][
#                                                                  0]']
#
#  dense_20 (Dense)               (None, 1, 1, 8)      512         ['reshape_10[0][0]']
#
#  dense_21 (Dense)               (None, 1, 1, 64)     512         ['dense_20[0][0]']
#
#  multiply_10 (Multiply)         (None, 128, 128, 64  0           ['activation_34[0][0]',
#                                 )                                 'dense_21[0][0]']
#
#  up_sampling2d_9 (UpSampling2D)  (None, 256, 256, 64  0          ['multiply_10[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 256, 256, 16  0           ['up_sampling2d_9[0][0]',
#                                 0)                                'block1_conv2[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 32  46112       ['concatenate_9[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 32  128        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 32  9248        ['activation_35[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 32  128        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  global_average_pooling2d_11 (G  (None, 32)          0           ['activation_36[0][0]']
#  lobalAveragePooling2D)
#
#  reshape_11 (Reshape)           (None, 1, 1, 32)     0           ['global_average_pooling2d_11[0][
#                                                                  0]']
#
#  dense_22 (Dense)               (None, 1, 1, 4)      128         ['reshape_11[0][0]']
#
#  dense_23 (Dense)               (None, 1, 1, 32)     128         ['dense_22[0][0]']
#
#  multiply_11 (Multiply)         (None, 256, 256, 32  0           ['activation_36[0][0]',
#                                 )                                 'dense_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 1)  33          ['multiply_11[0][0]']
#
#  activation_37 (Activation)     (None, 256, 256, 1)  0           ['conv2d_37[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 256, 256, 2)  0           ['activation_14[0][0]',
#                                                                   'activation_37[0][0]']
#
# ==================================================================================================
# Total params: 29,297,570
# Trainable params: 29,290,274
# Non-trainable params: 7,296
# __________________________________________________________________________________________________

# %%
model_path="/content/Files/model.h5"
csv_path="/content/Files/data.csv"
callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
]

# %%
model.fit(
        train_dataset,
        epochs=num_epoch,
        validation_data=valid_dataset,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps,
        callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 30/30 [==============================] - ETA: 0s - loss: 0.
saving model to /content/Files/model.h5
# 30/30 [==============================] - 79s 3s/step - loss: 0.0716 - dice_coef: 0.9060 - iou: 0.8297 - recall: 0.9804 - precision: 0.9805 - val_loss: 0.0832 - val_dice_coef: 0.9025 - val_iou: 0.8227 - val_recall: 0.9724 - val_precision: 0.9701 - lr: 1.0000e-05
# Epoch 46/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0709 - dice_coef: 0.9068 - iou: 0.8309 - recall: 0.9806 - precision: 0.9810
# Epoch 46: val_loss improved from 0.08321 to 0.08301, saving model to /content/Files/model.h5
# 30/30 [==============================] - 79s 3s/step - loss: 0.0709 - dice_coef: 0.9068 - iou: 0.8309 - recall: 0.9806 - precision: 0.9810 - val_loss: 0.0830 - val_dice_coef: 0.9029 - val_iou: 0.8232 - val_recall: 0.9722 - val_precision: 0.9704 - lr: 1.0000e-05
# Epoch 47/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0702 - dice_coef: 0.9075 - iou: 0.8321 - recall: 0.9809 - precision: 0.9813
# Epoch 47: val_loss improved from 0.08301 to 0.08285, saving model to /content/Files/model.h5
# 30/30 [==============================] - 80s 3s/step - loss: 0.0702 - dice_coef: 0.9075 - iou: 0.8321 - recall: 0.9809 - precision: 0.9813 - val_loss: 0.0828 - val_dice_coef: 0.9032 - val_iou: 0.8238 - val_recall: 0.9721 - val_precision: 0.9709 - lr: 1.0000e-05
# Epoch 48/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0696 - dice_coef: 0.9081 - iou: 0.8333 - recall: 0.9812 - precision: 0.9817
# Epoch 48: val_loss improved from 0.08285 to 0.08268, saving model to /content/Files/model.h5
# 30/30 [==============================] - 79s 3s/step - loss: 0.0696 - dice_coef: 0.9081 - iou: 0.8333 - recall: 0.9812 - precision: 0.9817 - val_loss: 0.0827 - val_dice_coef: 0.9035 - val_iou: 0.8243 - val_recall: 0.9721 - val_precision: 0.9712 - lr: 1.0000e-05
# Epoch 49/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0689 - dice_coef: 0.9088 - iou: 0.8343 - recall: 0.9814 - precision: 0.9821
# Epoch 49: val_loss improved from 0.08268 to 0.08250, saving model to /content/Files/model.h5
# 30/30 [==============================] - 79s 3s/step - loss: 0.0689 - dice_coef: 0.9088 - iou: 0.8343 - recall: 0.9814 - precision: 0.9821 - val_loss: 0.0825 - val_dice_coef: 0.9039 - val_iou: 0.8250 - val_recall: 0.9720 - val_precision: 0.9716 - lr: 1.0000e-05
# Epoch 50/50
# 30/30 [==============================] - ETA: 0s - loss: 0.0684 - dice_coef: 0.9094 - iou: 0.8354 - recall: 0.9816 - precision: 0.9824
# Epoch 50: val_loss improved from 0.08250 to 0.08233, saving model to /content/Files/model.h5
# 30/30 [==============================] - 80s 3s/step - loss: 0.0684 - dice_coef: 0.9094 - iou: 0.8354 - recall: 0.9816 - precision: 0.9824 - val_loss: 0.0823 - val_dice_coef: 0.9043 - val_iou: 0.8256 - val_recall: 0.9720 - val_precision: 0.9718 - lr: 1.0000e-05

# %%
model.save('/content/drive/MyDrive/Segmentation/PH2Models/PH2_double_Unet.hdf5')

# %%
create_dir("results")

# %%
def read_test_image(x):
    image = cv2.imread(x, cv2.IMREAD_COLOR)
    image = np.clip(image - np.median(image)+127, 0, 255)
    image = image/255.0
    image = image.astype(np.float32)
    image = np.expand_dims(image, axis=0)
    return image                              ## (1, 256, 256, 3)


def read_test_mask(y):
    mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
    mask = mask.astype(np.float32)
    mask = mask/255.0
    mask = np.expand_dims(mask, axis=-1)
    return mask
def mask_to_3d(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

def parse(y_pred):
    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = y_pred[..., -1]
    y_pred = y_pred.astype(np.float32)
    y_pred = np.expand_dims(y_pred, axis=-1)
    return y_pred

# %%
def evaluate_normal(model, x_data, y_data):
    THRESHOLD = 0.5
    total = []
    for i, (x, y) in tqdm(enumerate(zip(x_data, y_data)), total=len(x_data)):
        x = read_test_image(x)
        y = read_test_mask(y)
        _, h, w, _ = x.shape

        y_pred1 = parse(model.predict(x)[0][..., -2]>0.5)
        y_pred2 = parse(model.predict(x)[0][..., -1]>0.5)
        
        line = np.ones((h, 10, 3)) * 255.0
        
        all_images = [
            x[0] * 255.0, line,
            mask_to_3d(y) * 255.0, line,
            mask_to_3d(y_pred1) * 255.0, line,
            mask_to_3d(y_pred2) * 255.0
        ]
        mask = np.concatenate(all_images, axis=1)

        cv2.imwrite(f"results/{i}.png", mask)

# %%
evaluate_normal(model, test_x, test_y)
# Out:
# 100%|██████████| 160/160 [01:05<00:00,  2.43it/s]

# %%
model.compile(loss="binary_crossentropy", optimizer=Adam(lr), metrics=metrics)
model.load_weights('/content/drive/MyDrive/Segmentation/PH2Models/PH2_double_Unet.hdf5')

# %%
test_dataset=tf_dataset(test_x, test_y, batch_size)
test_steps = len(test_x)//batch_size

if len(test_x) % batch_size != 0:
  test_steps += 1
test_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 256, 256, 2), dtype=tf.float32, name=None))>

# %%
res=model.evaluate(train_dataset, steps=test_steps)
print('\n-------------On Train  Set--------------------------\n')
print('________________________')
print('Dice Coef:      |   {:.2f}  |'.format(res[1]*100))
print('IoU:            |   {:.2f}  |'.format(res[2]*100))
print('Recall:         |   {:.2f}  |'.format(res[3]*100))
print('Precision:      |   {:.2f}  |'.format(res[4]*100))
print('________________________')
res=model.evaluate(test_dataset, steps=test_steps)
print('\n-------------On Test  Set--------------------------\n')
print('________________________')
print('Dice Coef:      |   {:.2f}  |'.format(res[1]*100))
print('IoU:            |   {:.2f}  |'.format(res[2]*100))
print('Recall:         |   {:.2f}  |'.format(res[3]*100))
print('Precision:      |   {:.2f}  |'.format(res[4]*100))
print('________________________')
res=model.evaluate(valid_dataset, steps=test_steps)
print('\n-------------On valid  Set--------------------------\n')
print('________________________')
print('Dice Coef:      |   {:.2f}  |'.format(res[1]*100))
print('IoU:            |   {:.2f}  |'.format(res[2]*100))
print('Recall:         |   {:.2f}  |'.format(res[3]*100))
print('Precision:      |   {:.2f}  |'.format(res[4]*100))
print('________________________')
# Out:
# 10/10 [==============================] - 7s 673ms/step - loss: 0.0700 - dice_coef: 0.9088 - iou: 0.8333 - recall: 0.9840 - precision: 0.9769
#
# -------------On Train  Set--------------------------
#
# ________________________
# Dice Coef:      |   90.88  |
# IoU:            |   83.33  |
# Recall:         |   98.40  |
# Precision:      |   97.69  |
# ________________________
# 10/10 [==============================] - 7s 668ms/step - loss: 0.0811 - dice_coef: 0.9066 - iou: 0.8296 - recall: 0.9753 - precision: 0.9714
#
# -------------On Test  Set--------------------------
#
# ________________________
# Dice Coef:      |   90.66  |
# IoU:            |   82.96  |
# Recall:         |   97.53  |
# Precision:      |   97.14  |
# ________________________
# 10/10 [==============================] - 7s 672ms/step - loss: 0.0823 - dice_coef: 0.9043 - iou: 0.8256 - recall: 0.9720 - precision: 0.9718
#
# -------------On valid  Set--------------------------
#
# ________________________
# Dice Coef:      |   90.43  |
# IoU:            |   82.56  |
# Recall:         |   97.20  |
# Precision:      |   97.18  |
# ________________________
